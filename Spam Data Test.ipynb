# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import random

# %% [markdown]
# ## Real Data
# ### Spam Data
# https://archive.ics.uci.edu/ml/datasets/Spambase

# %%
spam = pd.read_csv("spambase.data", header = None).values

# %% [markdown]
# #### K-Means

# %%
label1, cost1, iter1, center1 = Kmeans(spam, 20)

# %%
plt.plot(cost1)
plt.xlabel("Iterations", fontsize = 12)
plt.ylabel("Cost -- Euclidean Distance", fontsize = 12)
plt.title("K-means, Iterations = {}".format(iter1))
pass

# %%
# %timeit Kmeans(spam, 20)
# Out:
# 733 ms ± 225 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### K-Means++

# %%
label2, cost2, iter2, centers2 = Kmeans_pp(spam, k=20)

# %%
plt.plot(cost2, color="orange")
plt.xlabel("Iterations", fontsize = 12)
plt.ylabel("Cost -- Euclidean Distance", fontsize = 12)
plt.title("K-means++, Iterations = {}".format(iter2))
pass

# %%
# %timeit Kmeans_pp(spam, k=20)
# Out:
# 169 ms ± 38.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### K-Meansll

# %%
label3, cost3, iter3, center3 = Kmeansll(spam, k=20, omega=0.5)

# %%
plt.plot(cost3)
plt.xlabel("Iterations", fontsize = 12)
plt.ylabel("Cost -- Euclidean Distance", fontsize = 12)
plt.title("K-meansll, Iterations = {}".format(iter3))
pass

# %%
# %timeit Kmeansll(spam, k=20, omega=0.5)
# Out:
# 2.2 s ± 223 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit Kmeansll(spam, k=20, omega=1)
# Out:
# 4.1 s ± 287 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit Kmeansll(spam, k=20, omega=2)
# Out:
# 7.95 s ± 449 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
plt.plot(cost3)
plt.plot(cost2)
plt.plot(cost1)
plt.legend(("K-Meansll, r = 0.5", "K-Means++", "K-Means"))
plt.xlabel("Iterations", fontsize = 12)
plt.ylabel("Cost -- Euclidean Distance", fontsize = 12)
plt.title("Spam Data")
pass
